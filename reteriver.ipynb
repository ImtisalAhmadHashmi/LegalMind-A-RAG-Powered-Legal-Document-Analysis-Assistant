# %%
from dotenv import load_dotenv
import os   

load_dotenv(override=True)

os.environ["HUGGINGFACE_API_KEY"] = os.getenv("HUGGINGFACE_API_KEY")

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("my_research_paper.pdf")

docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1'}, page_content="1 \n \nTHE DEVELOPMENT OF ARTIFICIAL INTELLIGENCE-BASED OPTIMAL \nROUTE SELECTION FRAMEWORK FOR RESCUE SERVICES PROCESS \nMANAGEMENT \nFahad M. Alqahtani 1, Imtisal Ahmad Hashmi 2, Imran Ahmad 2, Irfan Ahmed 3,4*, Mohammed Alkahtani 1 \n1 Industrial Engineering Department, College of Engineering, King Saud University, P.O. Box 800, Riyadh 11421, Saudi \nArabia; afahad@ksu.edu.sa, moalkahtani@ksu.edu.sa;  \n2 Department of Industrial Engineering, University of Engineering and Technology, Peshawar 25000, Pakistan; \nengrimtisalahmadhashmi@gmail.com, imranahmad@uetpeshawar.edu.pk \n3 Ayass BioScience LLC, Frisco, TX, USA,  \n4   Department of Electrical Engineering, University of Engineering and Technology, Peshawar 25000, Pakistan; \nirfanahmed@uetpeshawar.edu.pk \n* Correspondence: irfan.a@ayassbioscience.com \n \nThe increasing volume of vehicular services has intensified traffic congestion, leading to critical delays in healthcare services \nand a rise in fatalities due to road blockages. Unplanned blockage placements by law enforcement agencies further disrupt \ntraffic flow, increasing occupancy rates and impeding emergency response times. This study presents a data -driven \nframework that forecasts optimal blockage points and predicts congestion on alternative routes using a combination of \noperational research strateg ies and AI -based traffic modeling. The novelty of this work lies in leveraging AI -driven \noperational research techniques to optimize blockage placement while minimizing disruptions near healthcare and public \nsafety services. The framework employs supervise d machine learning models to classify traffic flow (non -congested: 0, \ncongested: 1) based on feature vectors linked to healthcare accessibility, achieving a 99% F1 score on both validation data \nand real -time traffic monitoring. Additionally, the A -star algorithm is utilized to determine the most efficient alternative \nroutes post -blockage. To enhance practical usability, the framework is integrated into a graphical user interface (GUI) \napplication capable of predicting congestion at specific time intervals t hroughout the day. This system serves as a decision -\nsupport tool for local agencies, aiding in strategic traffic planning and ensuring uninterrupted access to critical healthcar e \nservices. By mitigating congestion near essential service areas, the proposed  approach enhances emergency response \nefficiency and contributes to overall public safety. \n \nKeywords: Artificial Intelligence in Congestion Prediction; Healthcare; Smart Route Selection Process; Safety with Modern \nTechnology \n \n1. INTRODUCTION \n \nIn congested and developed small cities, urban sprawl has become a serious i ssue, leading to severe traffic congestion. A \nchallenging task to avoid congestion by the general public or the emergency services lies in determining the state of the traffic \non the roads. Traffic congestion is one of the major problems of big cities, caused by the increasing number of people living. \nTraffic congestion is caused when excess vehicles are on the road, causing traffic to slow down or even stop due to road \ncapacity being exceeded. The economy, the environment, and people's quality of life are all impacted by traffic congestion.       \n      An increasing amount of traffic data is produced daily due to the proliferation of vehicles, passengers, roadways, and \nroute combinations. Optimal route planning, intelligent transportation system implementation, traffic management and \nmonitoring system de sign, and many other applications can benefit from these traffic data. Researchers have gathered ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 1, 'page_label': '2'}, page_content='2 \n \nof AI to improve traffic management and society welfare can optimize traffic congestion by predictive route identification, \nwhich has numerous advantages, including positive effects on the economy, the environment, and reaction times to \nemergencies. The pr imary problem in dynamic traffic management is efficiently utilizing all routes based on their limited \nquantity and capacity. Typically, it is impractical to create new routes or expand road capabilities. Therefore, it is crucia l to \nfind strategies to optimize the use of the current transportation infrastructure [3]. \n      For this research, a crowded metropolis is used as a case study. Rising numbers of people living in cities and more people \nowning cars are a few of the many causes. Improving infrastructure, bolstering public transportation, implementing efficient \ntraffic management systems, and incorporating cutting-edge technology like AI are all necessary to address this problem and \nmake cities more accessible. The goal, in case of road blockage, is to utilize machine learning to predict the likelihood of \ntraffic on alternate routes. This will aid society as a whole by assisting traffic cops in better planning the route bottlenecks.  \n      The novelty of our work lies in adopting cutting edge data driven models for congestion prediction and optimal route \nsuggestion for smart cities in healthcare services. We employed ensemble Machine Learning (ML) models due to their \nscalable, adaptable, and  data-driven decision-making behavior by using data from the past to make informed decisions for \noptimal route selection for healthcare and rescue services. Optimizing traffic congestion through predictive route \nidentification has many benefits such as economic benefits, environmental impact, emergency response time, and \nempowering public planning leveraging AI to enhance overall traffic management and societal welfare.  \n      In this work, both conventional AI algorithms and ML methods were employed to forecast traffic conditions and possible \nalternate routes. ML models look for trends in historical data and, using that information as a foundation, these models \nforecast future outcomes of various variable combinations and choose the best one. The objective was to provide the \nhealthcare services, traffic police, and rescue services with more information to work with when making decisions and \nplanning the road obstructions.  In this study, the dataset taken in the form of velocity, flowrate, density, and output \nmeasurements were in real time. Accident and ambulance delay statistics are also part of our investigation to enhance the \nquality of healthcare and rescue services. \n \n2. Literature Review \n \nOne of the most basic necessities in modern civilization is fast mobility. People can so utilize a variety of modes of \ntransportation, including cars, subways, and bicycles. But despite all of these mobility options, cars continue to be the mos t \npopular because of their usefulness and comfort [4] According to the World Health Organization (WHO), delays caused \nby traffic congestion contribute to approximately 10 –15% of preventable deaths in emergency situations worldwide. \nIn major metropolitan cities, the av erage ambulance response time has significantly increased due to rising traffic \nvolumes; for instance, in New York City, emergency response times rose from 9.1 minutes in 2018 to 10.8 minutes in \n2022 [4-5]. In developing cities, response times often exceed 15 minutes , surpassing the golden hour standard crucial for \ntrauma and cardiac arrest cases. The Texas A&M Transportation Insti ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 2, 'page_label': '3'}, page_content="3 \n \nInfrared camera uses have been discussed in [13]. However, because infrared cameras are expensive, such applications are \nnot taken into consideration in this work. Google Maps is a digital mapping service created by Google that is the leading \nprovider of transportation information and advancements. Google Maps functions as a search tool for location-based services. \nGoogle Maps uses GPS data from the Google Maps app on cellphones through crowdsourcing. Google Maps has access to \nlocal municipality data throug h contracts, including road -specific information, road kinds, road maintenance, and speed \nlimits. \n      There are many existing approaches that address traffic congestion and optimizing road networks in urban areas. Traffic \nsignal optimization is a traditional method that uses fixed schedules or predefined traffic patterns to adjust signal timings , \naiming to minimize delay and maximize traffic flow. The traffic signals can be categorized in two categories fix time or traffic \nresponsive system [14]. Many algorithms have been used to improve the traffic signals, Reinforcement learning approach is \nmajor techniques used in multi agent system to improve the traffic signals [15,16] but the discrete nature of RL system was \nmajor limitation which was improved by using function approximation methods [17]. The responsive traffic system uses \npredictive models to pr edict the traffic flow at intersections and adjust the signal accordingly.  cooperative traffic signal \ncontroller has been introduced based on Deep Reinforcement Learning and traffic flow prediction. The local policies learned \nby traffic signal controller agents were transferred between the intersections [18]. \nIntelligent transportation system incorporates technologies like traffic cameras, sensors, and communication system to \nmonitor and manage traffic flow. Real -time information is provided to drivers through dynamic signs and speed limit \nadjustments, enabling informed decisions. Pulse laser light is used to find the distance of vehicles (Sanchez, Saito et al. 2017). \nVarious other techniques were used to in vehicle detection and localization are channel state information [8], received signal \nstrength indicator [9,19], link quality indicator and pocket loss rate [10]. \n      Traffic incident management is the effective management of incidents like accidents or road blockages is crucial to \nminimize their impact on traffic flow [32]. Traffic incidents are unpredictable thus cannot be controlled by normal measures. \nTraffic incidents occur randomly and lead to lane blockage, significantly decreasing the road's capacity. It can easily be \nmanaged by improving the road infrastructure but results in high cost [20]. To overcome the estimated cost, the readily \ndeveloped system can be improved by utilizing the intelligent transportation system technologies. Many countries have \ndeveloped the traffic incident management system based on these technologies [21]. \n      Many systems have been developed to improve the traffic flow during the emergency time, few of them are mentioned \nabove. The key aspect of these systems is utilizing up -to-date information or data and interpreting the results to effectively \nmanage and control the situation. Machine learning is now widely used to analyze the previous data and manage the traffic \nsystem efficiently. Machine learning process a vast amount of data by dealing with higher dimensionality [23,25], requiring \nmore efficient and quicker data processing that traditional approaches are unable to manage [22]. Machine Learning tools \ngather large amounts ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 3, 'page_label': '4'}, page_content='4 \n \n \nA. Abdelwahab, M., Kaysi, I., & Abdel -Aty, M. (2015). Real -time traffic management systems: A comprehensive \nreview. Journal of Intelligent Transportation Systems, 19(3), 233-253. \nB. Chen, X., Yang, X., Huang, H., & Zhang, Y. (2018). An intelligent transportation system for smart cities: A survey. \nIEEE Transactions on Intelligent Transportation Systems, 19(5), 1454-1469. \nC. Han, L., Qu, X., Zhang, H., & Xu, Y. (2018). A Survey of Dynamic Route Guidance Algorithms for Intelligent \nTransportation Systems. IEEE Transactions on Intelligent Transportation Systems, 19(4), 1195 -1209. \nD. Janowski, L., Diab, H., & Sengupta, R. (2021). Smart incident management system for urban traffic using edge \ncomputing. Transportation Research Part C: Emerging Technologies, 126, 103020.  \nE. Chen, S., Chen, Y., & Chen, C. (2018). Urban traffic prediction from spatio-temporal data using deep learning. IEEE \nTransactions on Intelligent Transportation Systems, 19(12), 3935-3944. \nF. Liu, Y., Wang, Y., & Luo, J. (2021). Designing Effective Public Information Systems for Traffic Management: \nInsights from a User-Centered Approach. Transportation Research Part A: Policy and Practice, 144, 194 -209. \n \n \n3. Methodology \n \nThe overall methodology of the research is illustrated in Figure 1. The workflow chart depicts all the crucial steps taken \nduring the end-to-end product development. In our work, system development started from system identification.  \n \nConceptual Model Development \n \nThe next step was the development of the conceptual model, where a rough sketch of the project was made, and specific goals \nwere defined. To achieve these goals, real -time traffic data was collected from Trans-Peshawar (a government institute) in \nPeshawar, Pakistan, and the latitude, and longitude of the selected points in the system and the distances between them were \ncollected from Google Maps,  followed by data processing techniques. AI models were trained and optimized based on the \navailable dataset to obtain improved results. Throughout these steps, Python libraries were used for data visualization and to \nanalyze alternative path selection mechanisms. Once validated, the system was deployed by integrating all components into \na user-friendly interface to enhance accessibility and effectiveness. \n \n3.1 Data Collection & Processing \n \nData on the death due to late arrival at the hospital was collected from “Provisional Monitoring Cell, Emergency Rescue \nServices, Government Of Khyber Pakhtunkhwa, Pakistan”. T hen to train a machine learning model for forecasting traffic \ncongestion, three variables were needed Density, Flowrate, and Velocity with output in binary format. Except for Density \nother variables were collected from Trans-Peshawar in Peshawar, Pakistan. Density was derived using a Macroscopic Traffic \nflow model.  \nThe key feature variables used for machine learning model training include:  \n• Velocity (Speed of vehicles in km/h) \n• Flow rate (Total vehicles passing through a specific location per hour) \n• Density (Number of vehicles per kilometer) \n      Apart from these variables, real -time traffic congestion statistics were also gathered from Google Maps. A total of 22 \ndifferent nodes were selected for which Map Data was required for implementing it in an alternative path algorithm. This \ndata includes information about the connections between nodes and the distance between them. Coordinating data was also \nneeded for visualizing a selected zone alternative path . It includes information about nodes and their respective latitude and \nlongitude coordinates. ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 4, 'page_label': '5'}, page_content="5 \n \n \nIn this study, the key features—density, flow rate, and velocity—were selected based on their relevance to traffic congestion \nprediction. The flow rate and velocity data were directly collected during the data collection phase as these are fundamental  \nindicators of traffic conditions. However, traffic density was not directly available in the data; therefore, it was derived using \na macroscopic traffic flow model equation, which is a well-established method in traffic flow theory. The macroscopic model \nlinks density, velocity, and flow rate, ensuring that the density data accurately reflects the traffic state. These features were \nchosen because velocity and flow rate provide direct measures of traffic movement, while density offers insight into the \nvehicle occupancy of a given road segment, a critical factor in congestion analysis. By incorporating these three features, we \nensured that the model captures a comprehensive view of traffic conditions, enhancing its predictive capability for congestion \nforecasting. The use of the macroscopic model to calculate density strengthened the overall model by allowing us to utilize \nall key traffic features for more accurate predictions \n \nSampling: \n \nThe area was pre-determined, and clustering was applied to the traffic data collected within this specific zone. The data points \nwere clustered based on varying traffic conditions such as vehicle density, vehicle average velocity, and traffic volume, which \nprovided a comprehensive understanding of congestion levels. The boundaries between smooth flow and congestion were \nestablished using these traffic-related thresholds, allowing for clear classification and differentiation between  various traffic \nstates. This approach ensured that the analysis accurately represented traffic conditions across the zone while maintaining \nconsistency in identifying congestion and smooth flow, thus addressing the reviewer's concern by offering a transparent and \nmethodologically sound approach. \n \n3.2 Data Processing \n \nBefore model training, the collected data was subjected to preprocessing techniques to enhance model learning and accuracy. \nThe following steps were taken to prepare the data for Machine Learning Model: \n• Handling Missing Values: Any missing data points were imputed using mean value substitution.  \nHandling Duplicate Values: All the duplicate values were dropped using the Numpy (Python Library) method.  \nHandling Outliers: First, a boxplot was used to identify the outliers we found the 1 st and the 3rd quantile of each feature data \npoint then any point below the 1 st quantile was changed to the 1 st quantile value, and any point above the 3rd quantile was \nchanged to the 3rd quantile value. \n• Normalization & Feature Scaling: Min-Max scaling was applied to normalize all numerical attributes. \nInput and Output Dataset: The output and the Input Features were separated \nTrain and Test Set: The Data was then divided into test and train datasets.  \n \n3.3 Model Development \n \nThe primary goal of this research was to develop a machine learning -based congestion prediction system, coupled with \noptimal route selection using AI algorithms. Several classical ML models were evaluated for their su itability in traffic \nprediction. The ML models used in our research work are listed below. \n1. Random Forest Classifier: Random Forest Classifier is an ensemble learning system that combines different decision trees \nfor predictions. It uses techniques like bagging and random feature selection to create diverse decision trees. Majority voting \nis employed to make t ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 5, 'page_label': '6'}, page_content='6 \n \nY=f (W*X +b) \nWhere: \n• Y is the output vector \n• X is the input vector \n• W is the weights matrix \n• b is the biased vector \n• f is the activation function \n5. Logistic Regression Classifier : Logistic regression is a statistical model for binary classification, estimating probabilities \nof binary outcomes. It uses the sigmoid function to convert a linear combination of input variables into probabilities. Model  \nparameters are estimated to minimize the error between predicted and actual values. Mathematical equation for is: \nY=Sigmoid(b1*x+b0) \nWhere: \nSigmoid=\n𝑒𝑥\n1+𝑒𝑥 \n6. Support Vector Classifier (SVC): Support Vector Classifier is a supervised learning technique for classification that finds \na hyperplane to separate data points into different classes. It introduces a slack variable to handle misclassification and \nincludes a regularization parameter. The objective is to find the best hyperplane while minimizing misclassification. The \nmodelling of SVC is based on the optimization problem, which involves objective functions and constraints. It can be written \nas: \nmin\n𝑤,𝑏\n|𝑤|, s.t y(W*X +b) ≥ 1 \n7. Decision Tree Classifier: Decision Tree Classification data points based on feature attributes using a tree like structure. It \nrecursively divides data based on feature thresholds to create decision nodes. The tree structure and decision rules are learned \nduring training to achieve accurate classification.  \nTo find the alternative path A- Star algorithm was used. \n8. A-Star Algorithm (A*): A-star is a path-finding algorithm used to find the shortest path between two points on a graph or \ngrid. It combines breadth-first and best-first search, using a heuristic function to guide the search. Nodes are prioritized based \non the cost function, and the algorithm iteratively explores and updates the path until reaching the goals.  \n \nModel Input: \n \n1. Machine Learning Models: \n \nDifferent ML models were compared. \nInput: \nDensity, Velocity, and Flowrate were the input variables of the Machine Learning Models.  \nOutput: \nOutput was binary with O indicating flow of the cars and 1 indicating traffic congestion.  \n  \n2. Shortest Path Algorithm:  \n \nThe shortest path algorithm (A-star Algorithm) was used to find the alternative path. The A -star algorithm needed map data \nto provide the shortest path. Map data including nodes and the connection of that node with other nodes with the distance \nbetween them.  To collect this data Google Maps was used. \nInput: \nThe starting Node and Destination node were given to the model as inputs. \nOutput: \nIt gave the shortest path between the starting and destination node. \n \nModel Selection: \n \nThe selection of machine learning models for this study was driven by their ability to handle classification tasks, particularly \nfor imbalanced datasets and the challenges posed by traffic congestion prediction. Random Forest Classifier was chosen for \nits robustness in high -dimensional data, class imbalance handling, and ensemble approach that mitigates overfitting. \nAdaBoost Classifier was included for its ability to improve weak classifiers iteratively, focusing on misclassified instances , \nmaking it effective for imbalanced datasets. Gradient Boosting Classifier was selected for its sequential error correction and'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 6, 'page_label': '7'}, page_content='7 \n \nhigh predictive accuracy in complex tasks like congestion forecasting. Multilayer Perceptron (MLP) Classifier was chosen \nfor its flexibility in learning complex, nonlinear patterns in high-dimensional data. Logistic Regression Classifier provided a \nsimple baseline for binary classification due to its interpretability, while Support Vector Classifier (SVC) was chosen for its \nability to handle non-linear separability and optimize the bias-variance tradeoff with regularization. Decision Tree Classifier \nwas included for its clear, interpretable rules and effectiveness with imbalanced datasets. Hyperparameters for each model \nwere fine -tuned based on prior literature and experimentation, optimizing factors such as the number of estimators and \nlearning rate for AdaBoost and maximum depth for Random Forest. To ensure model generalization and mitigate overfitting, \n10-fold cross-validation with stratified sampling was used, ensuring that the proportions of classes remained consistent across \nall folds. This method provi ded a robust estimate of model performance while maintaining the integrity of the imbalanced \ndataset \n \n3.4 Model Evaluation Metrics \n \nTo assess the performance of the proposed congestion prediction framework, three key evaluation metrics were utilized: \n1. F1 Score: Provides a balanced measure of Precision and Recall, critical in congestion classification tasks.  \n2. Accuracy: Measures the ratio of correctly predicted congestion cases to total test cases.  \n3. AUC -ROC (Area Under the Curve - Receiver Operating Characteristic): Evaluates how well the model distinguishes \nbetween traffic congestion and smooth flow. \n      As our problem was of classification all the used evaluation matrices were of classification. Accuracy was used to check \nthe general effectiveness of the model but accuracy alone can be misleading for an imbalanced dataset as out data was \nimbalanced data set so an F1 Score was used which helped us to be sure that our model was performing accurately as it gave \nequal importance to false negative and false positive. To above two evaluation matrices were also combined with AUC-ROC \nas it evaluated how well the model is separating the 0 and 1 cases across different thresholds. \nThe overall methodology of the research is illustrated in the form of Figure 1. The work flowchart depicts all the crucial \nsteps taken during the End -to-End product development. In our work, system development is started from system \nidentification. \n \n       \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nNext step was the development of the conceptual model where a rough sketch of the project was made and some goals \nwere defined. To achieve the goals, we collected a real time data from google maps and employed data processing techniques. \nAI models were tra ined to best fit the data and then optimized with respect to the available data to obtain improved results. \nDuring all these steps, we used open-source data visualization tools to observe the selection mechanism for alternate paths. To \ndeploy the validated system, we integrated all components and user -friendly interface was created to utilize the effectiveness \nof our developed model. \n \n3.1 Overview of the Machine Learning Models \n \nIn this work, the employment of ML for the optimal route selection is one the prime objectives. Therefore, classical ML models \nhave been thoroughly inspected to perform the task. In this section, we briefly overview each algorithm separately.  \nFigure 1. Research Methodology'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8'}, page_content="8 \n \nRandom Forest is one of the efficient ML models which lies within the category of ensemble classifier.  It is an ensemble \nlearning system that combines different decision trees for predictions. It uses techniques like bagging and random feature \nselection to create diverse decision trees. Majority voting is employed to make the final prediction, making it robust for high -\ndimensional data. Ada Boost Classifier is another ensemble learning technique that iteratively modifies weight and combines \npredictions from weak classifiers to create a strong classifier. Weak learners are trained, and their performance is evaluated \nand used to update data weight. This process continues iteratively, and a weighted majority vote is used for the final prediction. \nGradient Boosting is used as a classifier in our work. It sequentially constructs decision trees to reduce errors and make \nprecise predictions. It starts with a simple weak learner and computes residuals between actual and predicted values. Weak \nlearners are trained sequentially to minimize residuals and predictions are updated iteratively. With the recent advancements \nin deep learning, we were motivated to employ Artificial Neural Networks (ANN) in our work. Multilayer perceptron is an \nANN model used for classification purposes. It involves data preparation, weights initialization, feedforward propagation, loss \ncalculation, backpropagation, and iterative training. It can predict class probabilities and make class predictions based on \nneural network architecture.  \nLogistic regression is a statistical model for binary classification, estimating probabilities of binary outcomes. It uses the \nsigmoid function to convert a linear combination of input variables into probabilities. Model parameters are estimated to \nminimize the error between predicted and actual values. The use of Support Vector Classifier (SVC) is encouraged due to its \nperformance in many classicization tasks. SVC is a supervised learning model for classification that finds a hyperplane to \nseparate data points into different classes. It introduces a slack variable to handle misclassification and includes a regularization \nparameter. The objective is to find the best hyperplane while minimizing misclassification.  \nAs a part of a linear classifier, we used a Ridge Classifier. It uses ridge regression to address multicollinearity in data and \nadds a penalty term to the loss function to control model complexity. The trade -off between fitting the data and minimizing \nweights is governed by the regularization parameter (alpha). As part of a Random Forest, the utilization of Decision Tree is \nalso used as a separate tree -based classifier. It classifies data points based on feature attributes using a tree -like structure and \nrecursively divides data based on feature thresholds to create decision nodes. The tree structure and decision rules are learne d \nduring training to achieve accurate classification. Apart from the conventional ML algorithms, A -star is a pathfinding \nalgorithm used to find the shortest path between two points on a graph or grid. It combines breadth -first and best-first search, \nusing a heuristic function to guide the search. Nodes are prioritized based on the cost function, and the algorithm iterative ly \nexplores and updates the path until reaching the goals. \n \n3.2 Performance Evaluation Metrics \n \nIn this work, the performance evaluation of the proposed framework has been carried out by employing the subjective quality \nmeasures. The obtained metrics are based on the F1 score, Precision, Recall, and AUC -ROC score [ ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 8, 'page_label': '9'}, page_content='9 \n \n \nThe data employed for the development of framework has been collected from “Provisional Monitoring Cell, Emergency \nRescue Services. The training feature variables considered for ML model training for forecasting traffic congestion are density, \nflow rate, and velocity which are labelled with binary outputs. All other variables except density were collected from Trans -\nPeshawar (a government institute) in Peshawar, Pakistan. The corresponding values for density were manually calculated by \nusing a Macroscopic Traffic flow model given as: \nFlowrate =  Velocity ∗  Density (4)  \n      Then “Cluster Random Sampling Technique” was used to sample the data or the ML model. Data was collected considering \nthe Macroscopic Traffic flow model. Data collection and Data analysis took almost 45% time of the one-and-a-half-year-long \nproject. The only limitation of this data set is that the world is evolving so to utilize this in the current time it would be better \nto get the prediction on the recent data as the data collected was concerning the year this project was implemented.  Apart from \nthe desir ed training variables, we required map data for implementing an alternative path algorithm. This data includes \ninformation about nodes, connections between nodes and the distance between them. Also, coordinate data is needed for \nvisualizing a selected zone alternative path, which includes information about nodes and their respective latitude and longitude \ncoordinates. Therefore, we have selected over 22 different nodes and employed Google maps API to obtain coordinate data \nfor different zones. Coordinate data shows the latitude and longitude of the zone and the selected nodes. Also, the alternative \npath was discovered using the A-star algorithm, which needs location data to provide us the alternative path. All data including \nnodes location, interconnection among all nodes, and their distances is also collected from the Google Maps API.  \n      In our work, the experimented dataset has two feature variables, which are ‘Velocity’ and ‘Flowrate’, while the outcomes \nare labelled in a binary format (0: Flow, 1: Traffic congestion). As explained in previous sections, ‘Density’ is also calculated \nfrom the macroscopic traffic flow model and used as a feature variable [30]. \n      A macroscopic traffic flow model is employed to describe and analyze traffic behavior at an aggregate level, focusing on \nvariables like traffic density, flow rate, and velocity. These models help understand traffic patterns, predict congestion, a nd \nmake decisions related to transportation policies and infrastructure changes. \nThe employed model used three key input variables.  \n• Velocity: The speed of vehicles measured in kilometers per hour (km/h).  \n• Density: The number of vehicles per kilometer (v/km). \n• Flowrate: The total number of vehicles passing through a specific location in vehicles per hour (v/h)  \nThe model generates a binary output where “1” indicates traffic congestion jam situation and “0” represents smooth \ntraffic flow. \n      For the training of the ML model, a sampling technique is used which is called Cluster Random Sampling Technique. To \nsupport the problem statement, the number of deaths due to the late arrival at the hospitals was needed. The data was collected \nfrom the local provisional monitoring cell emergency rescue services. As per the available data, the number of deaths due to \nlate arrival at the hospital were 709 and the total number of deaths in the area over a year from 2022 to 2023 is 3300. This \ninformation is added as feature to compare the perfor ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 9, 'page_label': '10'}, page_content="10 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nAfter the identification zone, further profiling is conducted considering factors like road capacity, proximity to critical \nfacilities, and historical congestion patterns. This profiling helps understand the unique challenges and requirements of eac h \nzone, with a focus at Route 1. \n \n5. Experiments & Results \n5.1 Data Analysis, Preprocessing, & Visualization \n \nIn our work, vital features of the training data are extracted to improve the statistical learning of the employed models. \nTherefore, more features are added to enhance the learning capability of the employed models. As mentioned in previous \nsections, the “density” feature was not present in the collected dataset, so we used macroscopic model equation to calculate its \nvalue with reference to other values. Moreover, other features are scaled to have the coherent and uniform normalization \nfactors. \nThe statistical analysis of traffic patterns offers a systematic and quantitative method for comprehending, summarizing, \nand modeling traffic data, including aspects of traffic flow and congestion. Through the application of various statistical \ntechniques such as descriptive statistics, correlation analysis etc., it becomes possible to extract valuable insight, detect \nimportant patterns, and conclude decisions aimed at enhancing traffic management strategies and the overall transportation \nsystem. Table 2 represents the statistics of the data set that was used in this study. \n                                                          Table 2: Congestion Data Statistics \n \n \n \n \n \n \n \nWe have also made use of the Anderson -Darling test for data conformity with respect to a normal distribution after its \nscaling. The Anderson-Darling test is a statistical method used to check if a dataset confirms to a specific distribution, like the \nnormal distribution. It is more sensitive than the Kolmogorov – Smirnov test. The test calculates statistics by comparing \nobserved data to expected values based on the assumed distribution. This statistic is then compared to critical values to \ndetermine if the data significantly deviates from the assumed distribution. It's valuable for small to moderate –sized samples \nand can be applied to various distributions, aiding in hypothesis testing and model validation. Table 3 shows the result of \nAnderson Darling test for all parameters used and as all values are greater than 0.05 so all parameter’s data sets is following a \nnormal distribution, which can be visualized in Figure 3 which are for density, velocity, and flowrate respectively.   \n \n                                                              Table 3: Results of Anderson Darling Test \n \n \n \n \n \n \n \n \nS. No. Measure Flowrate Velocity Density Congestion \n1 Count 1559 1559 1559 1559 \n2 Mean 624.1 25.143 28.62 0.065427 \n3 Unit V / h  Km / h  V / Km No Unit \nAnderson Darling Test >0.05 \nP value for Density 0.605 \nP value for Flowrate 0.085 \nP value for Velocity 0.153 \n0\n0.2\n0.4\n0.6\n0.8\n1\n1.2\n10:00 12:24 14:48 17:12 19:36 22:00 0:24\nCongestion \nTime from 10AM to 10PM\nCongestion at Route 1\nFigure 2. Crucial Data Points"),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 10, 'page_label': '11'}, page_content='11 \n \n \n                                                Figure 3.  Anderson tests for  a) Density  b) Velocity  c) Flowrate \nIn order to get more insights of the available datasets, we used the correlation analysis. Correlation analysis is a statistical \nmethod used to assess the strength and direction of relationships between variables. In this project, this analysis was appli ed \nto evaluate the connection between density, velocity, and flowrate. The most common correlation is Pearson’s ranging from -\n1 to 1. A positive coefficient signifies variables rising together, like density and flow rate. Figure 4 represents the corre lation \nof parameters with each other and with the output. \n \nA 3D graph was generated to illustrate the correlation among congestion, velocity, and flow rate in traffic. Green and \nred were utilized as unique hues to symbolize varying traffic conditions: green for areas without congestion and red for \ncrowded areas. A  congestion number of 0 indicates smooth traffic flow, whereas other integer values indicate the relative \ntraffic flow. The graph accurately identified congested spots by analyzing flow rate and congestion value, enabling educated \njudgments and actions to reduce congestion and improve traffic flow in those specific locations. Figure 5 displays a \nrepresentation of the data sample, with green points representing flowing traffic data points and red points representing \ncongestion data points. \n(c) \n(a) (b)'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 11, 'page_label': '12'}, page_content='12 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n  \n5.2. Model Development \n \nWhen a route is blocked, the traffic is diverted to the alternative paths due to which congestion is created on the alternati ve \nroutes. To overcome this issue, the analytical modelling should be carried out that can predict the congestion on the alternative \npaths. The following steps are taken for a comprehensive framework development to fill the current research gaps regarding \nthe problem at hand. \n• An AI model should be selected which can predict traffic congestion most efficiently.  \n• An algorithm must be selected that can predict the alternative path on which the traffic will be diverted.  \n• The user must be able to predict the alternative path when a certain route is blocked.  \n• Predictions should be generated for the different sections of the alternative path to enhance accuracy and \ninformativeness. \n• The tool’s interface is designed to be user-friendly and easy to navigate. \nAs a preliminary work, we employed various Machine Learning (ML) models to predict traffic congestion as compared \nto the conventional methods. These models deployed different techniques like ensemble learning, neural networks, and \nregression to handle comp lex data patterns. Also, the reason for selecting these models was the ability of these models to \nFigure 4. Correlation matrix \nFigure 5. 3D Axis View for Congestion and Non-Congestion'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 12, 'page_label': '13'}, page_content="13 \n \nhandle complex relationships within the provided data consisting of “Density”, “Flowrate”, and “Velocity”. All these models, \nshown in Table 4, are analyzed and compared on the basis of subjective quality measures.  \n                                                       Table 4. Machine Learning Models \n      \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nTable 4 shows all the ML classification models used for this study where Random forest Classifier was selected for its \nrobustness, handles noisy data well and can capture complex relationships, whereas reason for the selection of  Ada Boost is \nthe handling of unbalance dataset and focuses more on what is misclassified in the by previous classifier which makes it pretty \nadaptive similarly Gradient Boost which builds sequential tree with each one learning from its previous mistakes and often \ndelivers high pre dictive accuracy. Logistic Regression Classifier for its binary classification and interpretability. Support \nVector classifier for its effectiveness in high dimensional spaces and for its versatility due to different kernel functions.  \nDecision Tree Classifier for its interpretable models that recursively splits the data based on features and to capture non-linear \ncomplex relationships while Ridge classifier to check how models for linearly separable data perform on our data set. MLP \nClassifier for its versatility for nonlinear problems and its capabilities of learning complex patterns through multiple layers.  \nIn this work, we utilized the K -fold cross-validation scheme for more robust evaluation. Cross -validation divides the \ndataset into k subsets (folds) and iteratively trains and evaluates the model using various combinations of these subsets. Th is \nhelps mitigate the impact of data variability and provides a more comprehensive assessment of model performance across \ndifferent data samples. Moreover, confusion matrix-based evaluation is also used to examine model performance in detail. The \nconfusion matrix tabulates values such as false positives, true positives, true negatives, and false negatives. It enables a deeper \nunderstanding of the model's ability to correctly identify both traffic congestion and non -congestion scenarios. \n To visually inspect the outcomes of the baseline and proposed models, we used an open -source Python library called \nFolium. It is used for generating interactive maps and displaying geospatial data. The platform provides a user -friendly \ninterface for creat ing maps, markers, polygons, and other map overlays. It is frequently utilized to showcase a variety of \ngeographical information, including locations, routes, and spatial patterns. Folium is utilized in areas such as data analysi s, \ndata visualization, and Geographic Information Systems (GIS). \n \n5.3. Model Deployment  \n \nCurrent study not only focuses on the model development, but the outcome of the project has been generated as a full -fledge \ndeployed model. For this purpose, we used a free web -based deployment tool, called Streamlit. Streamlit is an open -source \nPython library used for creating interactive web applications. It is particularly well suited for tasks related to data science and \nmachine learning. Developers can quickly build and deploy data -driven applications by writing simple Python scripts. \nStreamlit provide s an easy -to-use API for creating user interfaces, making it accessible to users with various levels of \nprogramming experience. With Streamlit, users can visualize data, generate plots and charts, and interact with machine \nlearning models through a clean and straigh ...
# ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 17, 'page_label': '18'}, page_content='18 \n \n5.7. Determining Alternative Path  \n \nAs iterated in the problem statement, our work not only determined the congestion but an alternate path is also determined to  \nfully equip the functionality of the proposed framework. In this work, we used A -star (A*) algorithm, which is a popular \npathfinding algorithm. Its efficiency in cost ( g) and estimated goal cost ( h) balancing was the motive behind its application. \nDue to its efficiency for large networks, it ensures the best route with consistent, non -overestimating heuristic (h).  \n \n  \n \n \n \n \n \nAfter our system has encountered the road blockage prediction at certain node, the A-star algorithm successfully generates \nthe alternative path which is plotted using Folium. In Figure 11a, the red spot shows the block placed by the user, the visib le \nnodes show the alternative path nodes out of the selected path, and the green joining the nodes shows the alternative path. \nAlso, in Figure 11b, no block is placed so it shows the shortest path between two nodes without the blocking of the node.  \n \n5.8. Application Deployment \n \nIn last step, the developed system has been deployed as a full -fledge application by using the Streamlit . In the application \ninterface, a user has the following options: \n• “Starting node”, “Destination node”, and “Blocking node” (where he wants to put the block) as the inputs.  \n• The user has four different options in the drop-down menu “See Selected path” where the user can visualize the selected \nzone (Figure 12). \n• “Blocking Node Map” where the user visualizes the selected nodes and can decide which node to block.  \n• “Visualize The Alternative Path” where the user can visualize the alternative path after the block is placed (Figure 13).  \n• “Generate Congestion prediction” where the user can visualize the predictions on the alternative path the block is placed. \nHere user can select for which segment of the alternative path he wants the congestion predictions from another drop -down \noption. \nThe predictions are displayed in four different colors red (75%-100% congestion chances), Orange (50%-74% congestion \nchances), Yellow (25%-49% congestion chances), and green (0%-24% congestion chances). \n \n (a) (b) \nFigure 11. (a) Alternative path between two nodes generated by A-Star algorithm after placing a \nblock. (b) Actual path between two nodes generated by A-Star algorithm before placing a block.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 18, 'page_label': '19'}, page_content='19 \n \n \n \n \n \n \n \n \n6. Sustainable Development Goals (SDGs) \n \nIn this work, following SDGs have been targeted: \n• Goal 3: Good Health and Well -being: By reducing traffic congestion, we aim to improve emergency response times, \npotentially saving lives and ensuring timely access to healthcare facilities. \n• Goal 9: Industry, Innovation, and Infrastructure: This project utilizes Artificial Intelligence and algorithms to optimize \nroute selection, enhancing transportation infrastructure and efficiency. \n• Goal 11: Sustainable Cities and Communities:  Addressing traffic congestion promotes sustainable urban development \nby reducing air pollution, improving mobility, and enhancing the overall quality of life.  \n• Goal 13: Climate Action: By minimizing congestion and improving traffic flow, our project indirectly contributes to \nreducing greenhouse gas emissions associated with traffic congestion. \n• Goal 17: Partnerships for the Goals: This project’s collaboration with the Traffic Police, rescue services, and public \nstakeholders demonstrates the importance of partnerships to achieve sustainable solutions.  \n \n7. Conclusion \n \nNew conclusion:  This study presents a comprehensive framework for addressing unanticipated road blockages and urban \ntraffic congestion through predictive analytics and intelligent route optimization. By leveraging the AdaBoost Classifier, th e \nFigure 12. Route visualization in Map \n \nFigure 13. Alternative Path After the Blocked Path'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 19, 'page_label': '20'}, page_content="20 \n \nsystem achieves high predictive accuracy (99.87%) with an F1-score of 99.86% and an AUC-ROC score of 99.74%, ensuring \nprecise congestion forecasting. The integration of the A-Star algorithm enables dynamic alternative route selection, optimizing \ntraffic flow and minimizing disruptions. A web -based interface facilitates real -time decision-making for traffic authorities, \nemergency responders, healthcare officials, and rescue services, enhancing operational efficiency. Additionally, the system \nprovides data th at helps plan road blockages in locations where the probability of traffic congestion is minimal, particularly \nalong routes connecting the health and wellness sectors. This allows for better planning of health services and rescue \noperations, ensuring that emergency vehicles can travel with minimal delay, even in the event of unforeseen blockages. Beyond \ncomputational efficacy, this research highlights the socio -economic impact of congestion by incorporating ambulance delay \nand casualty data, underscoring it s significance for public welfare. The findings demonstrate the practical applicability of \nmachine learning in intelligent transportation systems, offering a scalable and adaptive solution for urban mobility challenges. \nFuture enhancements include real-time data integration from GPS, IoT-enabled sensors, and traffic cameras to improve system \nresponsiveness, while collaboration with municipal authorities and emergency services will refine predictive capabilities and  \nensure effective deployment. Ultimately, t his research contributes to the advancement of smart traffic management systems, \nshowcasing the synergy between artificial intelligence, optimization algorithms, and urban mobility solutions for sustainable  \nand efficient transportation networks, with a strong focus on health and rescue services \n \nOld Conclusion: This study focuses on the pressing issue of unanticipated road blockages in urban areas and proposes \na solution that involves congestion prediction as well as alternative path identification. The proposed framework employs \nmachine learning algorithms for t he prediction of congestion specifically Ada Boost Classifier, the developed tool achieved \n99.86% F1 Score, 99.87% Accuracy score, and 99.74% AUC -ROC score in predicting traffic congestion. The use of the A -\nStar algorithm for alternative pa th selection further ensures optimal routes are identified, enhancing overall traffic \nmanagement. Apart from the analytical results, a web -based interface has been developed which offers a user -friendly \nexperience for traffic police, healthcare officials, and rescue officers to enable them make informed decisions about road \nblockages and anticipate congestion on alternative routes. This study not only contributes to traffic management strategies but \nalso considers public welfare by addressing the impact on emergency services, as evidenced by the inclusion of ambulance \ndelay and casualties’ data. The significance of the project extends beyond the immediate problem, offering a potential solution \nto mitigate the economic, environmental, and societal impact of t raffic congestion. Furthermore, the project showcases the \nversatility of machine learning in real-world applications and provides a scalable solution that can be applied to other congested \nurban areas. For future work, there is potential to enhance the too l's accuracy and usability by incorporating real -time data \nfrom various sources, such as GPS and traffic cameras. Additionally, collaboration with local authorities and emergency \nservices can lead to a mor ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 20, 'page_label': '21'}, page_content='21 \n \nproject administration, M.A.; funding acquisition, M.A. All authors have read and agreed to the published version of the \nmanuscript. \nFunding: This work was supported by the Researchers Supporting Project Number (RSP2024R274), King Saud University, \nRiyadh, Saudi Arabia. \nData Availability Statement: Data will be available on request. \n \nAcknowledgments: The authors would like to thank the Researchers Supporting Project Number (RSP2024R274), King Saud \nUniversity, Riyadh, Saudi Arabia for funding this research work. \nConflicts of Interest: The authors declare no conflict of interest. \nReferences: \n1. Loumiotis, I.; Demestichas, K.; Adamopoulou, E.; Kosmides, P.; Asthenopoulos, V.; Sykas, E. Road traffic prediction using \nartificial neural networks. In Proceedings of the 2018 South -Eastern European Design Automation, Computer Engineering, \nComputer Networks and Society Media Conference (SEEDA_CECNSM), 2018; pp. 1-5. \n2. Meena, G.; Sharma, D.; Mahrishi, M. Traffic prediction for intelligent transportation system using machine learning. In \nProceedings of the 2020 3rd International Conference on Emerging Technologies in Computer Engineering: Machine Learning \nand Internet of Things (ICETCE), 2020; pp. 145-148. \n3. Celtek, S.A.; Durdu, A.; Alı, M.E.M. Real-time traffic signal control with swarm optimization methods. Measurement 2020, \n166, 108206. \n4. Djahel, S.; Doolan, R.; Muntean, G.-M.; Murphy, J. A communications-oriented perspective on traffic management systems \nfor smart cities: Challenges and innovative approaches. IEEE Communications Surveys & Tutorials 2014, 17, 125 -151. \n5. Karagiannis, G.; Altintas, O.; Ekici, E.; Heijenk, G.; Jarupan, B.; Lin, K.; Weil, T. Vehicular networking: A survey and \ntutorial on requirements, architectures, challenges, standards and solutions. IEEE communications surveys & tutorials 2011, \n13, 584-616. \n6. De Souza, A.M.; Yokoyama, R.S.; Maia, G.; Loureiro, A.; Villas, L. Real-time path planning to prevent traffic jam through \nan intelligent transportation system. In Proceedings of the 2016 IEEE symposium on computers and communication (ISCC), \n2016; pp. 726-731. \n7. Systematics, C. Traffic congestion and reliability: Trends and advanced strategies for congestion mitigation; United State s. \nFederal Highway Administration: 2005. \n8. Won, M.; Zhang, S.; Son, S.H. WiTraffic: Low-cost and non-intrusive traffic monitoring system using WiFi. In Proceedings \nof the 2017 26th International Conference on Computer Communication and Networks (ICCCN), 2017; pp. 1 -9. \n9. Šoštarić, D.; Martinovic, G.; Žagar, D. GPS tracking of self -balancing vehicle for extreme environment based on \nAndroidOS. In Proceedings of the 2012 20th Telecommunications Forum (TELFOR), 2012; pp. 1060 -1063. \n10. Roy, S.; Sen, R.; Kulkarni, S.; Kulkarni, P.; Raman, B.; Singh, L.K. Wireless across road: RF based road traffic congestion \ndetection. In Proceedings of the 2011 Third International Conference on Communication Systems and Networks (COMSNETS \n2011), 2011; pp. 1-6. \n11. Kassem, N.; Kosba, A.E.; Youssef, M. RF-based vehicle detection and speed estimation. In Proceedings of the 2012 IEEE \n75th vehicular technology conference (VTC Spring), 2012; pp. 1-5. \n12. Rüfenacht, D.; Fredembach, C.; Süsstrunk, S. Automatic and accurate shadow detection using near -infrared information. \nIEEE transactions on pattern analysis and machine intelligence 2013, 36, 1672 -1678. \n13. Gade, R.; Moeslund, T.B. Thermal cameras and applications: a survey. Machine vision and applications 2014, 25, 245 -\n262. \n14. Zheng, X.; Recker, W. An adaptive control algorithm ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 21, 'page_label': '22'}, page_content='22 \n \n22. Delnevo, G.; Di Lena, P.; Mirri, S.; Prandi, C.; Salomoni, P. On combining Big Data and machine learning to support eco-\ndriving behaviours. Journal of Big Data 2019, 6, 1-15. \n23. Ahmed, I; Khan, A; Ahmad, N, Minallah, N; Ali, H. Speech Signal Recovery Using Block Sparse Bayesian Learning. \nArabian Journal for Science and Engineering 2019, 45, 1567-1569. \n24. Shang, Q.; Tan, D.; Gao, S.; Feng, L. A hybrid method for traffic incident duration prediction using BOA -optimized \nrandom forest combined with neighborhood components analysis. Journal of Advanced Transportation 2019, 2019.  \n25. Ahmed, I; Khalil, A; Ahmed, I; Jaroslav, F. Sparse Signal Reconstruction, Sampling, and Recovery in Compressive \nSensing Frameworks. IEEE Access 2022, 10, 85002-85018. \n26. Boyles, S.; Fajardo, D.; Waller, S.T. A naive Bayesian classifier for incident duration prediction. In Proceedings of the  \n86th Annual Meeting of the Transportation Research Board, Washington, DC, 2007.  \n27. Ahmed, I; Alkahtani, M; Khalid, Q; Alqahtani, F. Improved Commodity Supply Chain Performance through AI and \nComputer Vision Techniques. IEEE Access 2024, 12, 24116-24132. \n28. Araghi, B.N.; Hu, S.; Krishnan, R.; Bell, M.; Ochieng, W. A comparative study of k -NN and hazard -based models for \nincident duration prediction. In Proceedings of the 17th International IEEE Conference on Intelligent Transportation Systems \n(ITSC), 2014; pp. 1608-1613. \n29. Ahmed, I; Khan, A. Learning based Speech Compressive Subsampling. Multimedia Tools & Applications 2023, 82, 15327-\n15343. \n30. Park, H.; Haghani, A. Real -time prediction of secondary incident occurrences using vehicle probe data. Transportation \nResearch Part C: Emerging Technologies 2016, 70, 69-85. \n31. Kozan E. A New Estimation Approach in Machine Learning Regression Model. International Journal of Industrial \nEngineering: Theory, Applications and Practice. 2024;31(4). \n32. Nadar RA, Jha JK, Thakkar JJ. Performance Evaluation of Performance Evaluation of Emergency Medical Service Systems \nwith Multiple Ambulance Types and Patient Types. International Journal of Industrial Engineering: Theory, Applications and \nPractice. 2024;31(4). \n33. Bektur G, Nembhard D. A multi -objective approach to home health care routing problem with team formation. \nInternational Journal of Industrial Engineering: Theory, Applications and Practice. 2023 Jan 1;30(5).  \n \n \n[4] World Health Organization (WHO). Global Status Report on Road Safety 2018. Geneva: WHO, 2018. \n[5] New York City Fire Department (FDNY), Annual EMS Response Time Report, 2022. \n[6] Texas A&M Transportation Institute (TTI). Urban Mobility Report 2021, Texas A&M University, 2021.')]

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

texts = text_splitter.split_documents(docs)

# %%
texts[:5]
# Out:
# [Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1'}, page_content='1 \n \nTHE DEVELOPMENT OF ARTIFICIAL INTELLIGENCE-BASED OPTIMAL \nROUTE SELECTION FRAMEWORK FOR RESCUE SERVICES PROCESS \nMANAGEMENT \nFahad M. Alqahtani 1, Imtisal Ahmad Hashmi 2, Imran Ahmad 2, Irfan Ahmed 3,4*, Mohammed Alkahtani 1 \n1 Industrial Engineering Department, College of Engineering, King Saud University, P.O. Box 800, Riyadh 11421, Saudi \nArabia; afahad@ksu.edu.sa, moalkahtani@ksu.edu.sa;  \n2 Department of Industrial Engineering, University of Engineering and Technology, Peshawar 25000, Pakistan; \nengrimtisalahmadhashmi@gmail.com, imranahmad@uetpeshawar.edu.pk \n3 Ayass BioScience LLC, Frisco, TX, USA,  \n4   Department of Electrical Engineering, University of Engineering and Technology, Peshawar 25000, Pakistan; \nirfanahmed@uetpeshawar.edu.pk \n* Correspondence: irfan.a@ayassbioscience.com \n \nThe increasing volume of vehicular services has intensified traffic congestion, leading to critical delays in healthcare services'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1'}, page_content='* Correspondence: irfan.a@ayassbioscience.com \n \nThe increasing volume of vehicular services has intensified traffic congestion, leading to critical delays in healthcare services \nand a rise in fatalities due to road blockages. Unplanned blockage placements by law enforcement agencies further disrupt \ntraffic flow, increasing occupancy rates and impeding emergency response times. This study presents a data -driven \nframework that forecasts optimal blockage points and predicts congestion on alternative routes using a combination of \noperational research strateg ies and AI -based traffic modeling. The novelty of this work lies in leveraging AI -driven \noperational research techniques to optimize blockage placement while minimizing disruptions near healthcare and public \nsafety services. The framework employs supervise d machine learning models to classify traffic flow (non -congested: 0,'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1'}, page_content='safety services. The framework employs supervise d machine learning models to classify traffic flow (non -congested: 0, \ncongested: 1) based on feature vectors linked to healthcare accessibility, achieving a 99% F1 score on both validation data \nand real -time traffic monitoring. Additionally, the A -star algorithm is utilized to determine the most efficient alternative \nroutes post -blockage. To enhance practical usability, the framework is integrated into a graphical user interface (GUI) \napplication capable of predicting congestion at specific time intervals t hroughout the day. This system serves as a decision -\nsupport tool for local agencies, aiding in strategic traffic planning and ensuring uninterrupted access to critical healthcar e \nservices. By mitigating congestion near essential service areas, the proposed  approach enhances emergency response \nefficiency and contributes to overall public safety.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1'}, page_content="services. By mitigating congestion near essential service areas, the proposed  approach enhances emergency response \nefficiency and contributes to overall public safety. \n \nKeywords: Artificial Intelligence in Congestion Prediction; Healthcare; Smart Route Selection Process; Safety with Modern \nTechnology \n \n1. INTRODUCTION \n \nIn congested and developed small cities, urban sprawl has become a serious i ssue, leading to severe traffic congestion. A \nchallenging task to avoid congestion by the general public or the emergency services lies in determining the state of the traffic \non the roads. Traffic congestion is one of the major problems of big cities, caused by the increasing number of people living. \nTraffic congestion is caused when excess vehicles are on the road, causing traffic to slow down or even stop due to road \ncapacity being exceeded. The economy, the environment, and people's quality of life are all impacted by traffic congestion."),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1'}, page_content="capacity being exceeded. The economy, the environment, and people's quality of life are all impacted by traffic congestion.       \n      An increasing amount of traffic data is produced daily due to the proliferation of vehicles, passengers, roadways, and \nroute combinations. Optimal route planning, intelligent transportation system implementation, traffic management and \nmonitoring system de sign, and many other applications can benefit from these traffic data. Researchers have gathered and \nprocessed traffic data with varying technical features and operational variables using a variety of data collection \nmethodologies. The utilization of  crowd-sourcing technologies based on Global Positioning System (GPS) has been \nextensively employed in the collection of traffic data. In most cases, a management system will use real -time Google Maps \nto assess routes depending on the current traffic condi tions. When it comes to emergency services, the selection of traffic")]

# %%
model_name = "google/gemma-3-1b-it"
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name=model_name)
# Out:
# No sentence-transformers model found with name google/gemma-3-1b-it. Creating a new one with mean pooling.
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Some weights of Gemma3TextModel were not initialized from the model checkpoint at google/gemma-3-1b-it and are newly initialized: ['embed_tokens.weight', 'layers.0.input_layernorm.weight', 'layers.0.mlp.down_proj.weight', 'layers.0.mlp.gate_proj.weight', 'layers.0.mlp.up_proj.weight', 'layers.0.post_attention_layernorm.weight', 'layers.0.post_feedforward_layernorm.weight', 'layers.0.pre_feedforward_layernorm.weight', 'layers.0.self_attn.k_norm.weight', 'layers.0.self_attn.k_proj.weight', 'layers.0.self_attn.o_proj.weight', 'layers.0.self_attn.q_norm.weight', 'layers.0.self_attn.q_proj.weight', 'layers.0.self_attn.v_proj.weight', 'layers.1.input_layernorm.weight', 'layers.1.mlp.down_proj.weight', 'layers.1.mlp.gate_proj.weight', 'layers.1.mlp.up_proj.weight', 'layers.1.post_attention_layernorm.weight', 'layers.1.post_feedforward_layernorm.weight', 'layers.1.pre_feedforward_layernorm.weight', 'layers.1.self_attn.k_norm.weight', 'layers.1.self_attn.k_proj.weight', 'layers.1.self_attn.o_proj.weight', 'layers.1.self_attn.q_norm.weight', 'layers.1.self_attn.q_proj.weight', 'layers.1.self_attn.v_proj.weight', 'layers.10.input_layernorm.weight', 'layers.10.mlp.down_proj.weight', 'layers.10.mlp.gate_proj.weight', 'layers.10.mlp.up_proj.weight', 'layers.10.post_attention_layernorm.weight', 'layers.10.post_feedforward_layernorm.weight', 'layers.10.pre_feedforward_layernorm.weight', 'layers.10.self_attn.k_norm.weight', 'layers.10.self_attn.k_proj.weight', 'layers.10.self_attn.o_proj.weight', 'layers.10.self_attn.q_norm.weight', 'layers.10.self_attn.q_proj.weight', 'layers.10.self_attn.v_proj.weight', 'layers.11.input_layernorm.weight', 'layers.11.mlp.down_proj.weight', 'layers.11.mlp.gate_proj.weight', 'layers.11.mlp.up_proj.weight', 'layers.11.post_attention_layernorm.weight', 'layers.11.post_feedforward_layernorm.weight', 'layers.11.pre_feedforward_layernorm.weight', 'layers.11.self_attn.k_norm.weight', 'layers.11.self_attn.k_proj.weight', 'layers.11.self_attn.o_proj.weight', 'layers.11.self_attn.q_norm.weight', 'layers.11.self_attn.q_proj.weight', 'layers.11.self_attn.v_proj.weight', 'layers.12.input_layernorm.weight', 'layers.12.mlp.down_proj.weight', 'layers.12.mlp.gate_proj.weight', 'layers.12.mlp.up_proj.weight', 'layers.12.post_attention_layernorm.weight', 'layers.12.post_feedforward_layernorm.weight', 'layers.12.pre_feedforward_layernorm.weight', 'layers.12.self_attn.k_norm.weight', 'layers.12.self_attn.k_proj.weight', 'layers.12.self_attn.o_proj.weight', 'layers.12.self_attn.q_norm.weight', 'layers.12.self_attn.q_proj.weight', 'layers.12.self_attn.v_proj.weight', 'layers.13.input_layernorm.weight', 'layers.13.mlp.down_proj.weight', 'layers.13.mlp.gate_proj.weight', 'layers.13.mlp.up_proj.weight', 'layers.13.post_attention_layernorm.weight', 'layers.13.post_feedforward_layernorm.weight', 'layers.13.pre_feedforward_layernorm.weight', 'layers.13.self_attn.k_norm.weight', 'layers.13.self_attn.k_proj.weight', 'layers.13.self_attn.o_proj.weight', 'layers.13.self_attn.q_norm.weight', 'layers.13.self_attn.q_proj.weight', 'layers.13.self_attn.v_proj.weight', 'layers.14.input_layernorm.weight', 'layers.14.mlp.down_proj.weight', 'layers.14.mlp.gate_proj.weight', 'layers.14.mlp.up_proj.weight', 'layers.14.post_attention_layernorm.weight', 'layers.14.post_feedforward_layernorm.weight', 'layers.14.pre_feedforward_layernorm.weight', 'layers.14.self_attn.k_norm.weight', 'layers.14.self_attn.k_proj.weight', 'layers.14.self_attn.o_proj.weight', 'layers.14.self_attn.q_norm.weight', 'layers.14.self_attn.q_proj.weight', 'layers.14.self_attn.v_proj.weight', 'layers.15.input_layernorm.weight', 'layers.15.mlp.down_proj.weight', 'layers.15.mlp.gate_proj.weight', 'layers.15.mlp.up_proj.weight', 'layers.15.post_attention_layernorm.weight', 'layers.15.post_feedforward_layernorm.weight', 'layers.15.pre_feedforward_layernorm.weight', 'layers.15.self_attn.k_norm.weight', 'layers.15.self_attn.k_proj.weight', 'layers.15.self_attn.o_proj.weight', 'layers.15.self ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`

# %%
from langchain_community.vectorstores import FAISS
import faiss

db = FAISS.from_documents(texts, embeddings)

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# %%
pipe = pipeline("text-generation", 
                model=model, 
                tokenizer=tokenizer, 
                device=-1, # 0 for cuda and -1 for cpu
                temperature=0.1)
# Out:
# Device set to use cpu

# %%
llm = HuggingFacePipeline(pipeline=pipe)

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_template("""
Answer the following question based only on the provided context.
Think step by step before providing a detailed answer
Make sure the answer is well structured and easy to understand
<context>
{context}
</context>
Question: {input}""")

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain

document_chain = create_stuff_documents_chain(llm,prompt)

# %%
#initializing the retriever

retriever = db.as_retriever()

retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x0000025D928D7380>, search_kwargs={})

# %%
from langchain.chains import create_retrieval_chain

retrieval_chain = create_retrieval_chain(retriever, document_chain)

# %%
question ="What are the main contributions of the paper?"

# %%
response = retrieval_chain.invoke({"input": question})

# %%
response
# Out:
# {'input': 'What are the main contributions of the paper?',
#  'context': [Document(id='96a09982-a5de-4b6e-9d5e-4ac75abbff52', metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 4, 'page_label': '5'}, page_content='the output for binary or multiclass classification. It involves  initializing weights, feedforward propagation, loss calculation, \nbackpropagation, and iterative training mechanisms. Mathematically it can be written as:'),
#   Document(id='f031f360-5fac-4681-9c21-be7a9f09fbde', metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 19, 'page_label': '20'}, page_content='ensure effective deployment. Ultimately, t his research contributes to the advancement of smart traffic management systems, \nshowcasing the synergy between artificial intelligence, optimization algorithms, and urban mobility solutions for sustainable  \nand efficient transportation networks, with a strong focus on health and rescue services \n \nOld Conclusion: This study focuses on the pressing issue of unanticipated road blockages in urban areas and proposes \na solution that involves congestion prediction as well as alternative path identification. The proposed framework employs \nmachine learning algorithms for t he prediction of congestion specifically Ada Boost Classifier, the developed tool achieved \n99.86% F1 Score, 99.87% Accuracy score, and 99.74% AUC -ROC score in predicting traffic congestion. The use of the A -\nStar algorithm for alternative pa th selection further ensures optimal routes are identified, enhancing overall traffic'),
#   Document(id='d1d8c16f-7633-4762-b63d-1e23032310ba', metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 6, 'page_label': '7'}, page_content='of our developed model. \n \n3.1 Overview of the Machine Learning Models \n \nIn this work, the employment of ML for the optimal route selection is one the prime objectives. Therefore, classical ML models \nhave been thoroughly inspected to perform the task. In this section, we briefly overview each algorithm separately.  \nFigure 1. Research Methodology'),
#   Document(id='aa665d09-6669-4f20-9496-c524913e7044', metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-07-31T19:51:56+05:00', 'author': 'IJIETAP Assistant Editor', 'moddate': '2025-07-31T19:51:56+05:00', 'source': 'my_research_paper.pdf', 'total_pages': 22, 'page': 17, 'page_label': '18'}, page_content='• “Visualize The Alternative Path” where the user can visualize the alternative path after the block is placed (Figure 13).  \n• “Generate Congestion prediction” where the user can visualize the predictions on the alternative path the block is placed. \nHere user can select for which segment of the alternative path he wants the congestion predictions from another drop -down \noption. \nThe predictions are displayed in four different colors red (75%-100% congestion chances), Orange (50%-74% congestion \nchances), Yellow (25%-49% congestion chances), and green (0%-24% congestion chances). \n \n (a) (b) \nFigure 11. (a) Alternative path between two nodes generated by A-Star algorithm after placing a \nblock. (b) Actual path between two nodes generated by A-Star algorithm before placing a block.')],
#  'answer': 'Human: \nAnswer the following question based only on the provided context.\nThink step by step before providing a detailed answer\nMake sure the answer is well structured and easy to understand\n<context>\nthe output for binary or multiclass classification. It involves  initializing weights, feedforward propagation, loss calculation, \nbackpropagation, and iterative training mechanisms. Mathematically it can be written as:\n\nensure effective deployment. Ultimately, t his research contributes to the advancement of smart traffic management systems, \nshowcasing the synergy between artificial intelligence, optimization algorithms, and urban mobility solutions for sustainable  \nand efficient transportation networks, with a strong focus on health and rescue services \n \nOld Conclusion: This study focuses on the pressing issue of unanticipated road blockages in urban areas and proposes \na solution that involves congestion prediction as well as alternative path identification. The proposed framework employs \nmachine learning algorithms for t he prediction of congestion specifically Ada Boost Classifier, the developed tool achieved \n99.86% F1 Score, 99.87% Accuracy score, and 99.74% AUC -ROC score in predicting traffic congestion. The use of the A -\nStar algorithm for alternative pa th selection further ensures optimal routes are identified, enhancing overall traffic\n\nof our developed model. \n \n3.1 Overview of the Machine Learning Models \n \nIn this work, the employment of ML for the optimal route selection is one the prime objectives. Therefore, classical ML models \nhave been thoroughly inspected to perform the task. In this section, we briefly overview each algorithm separately.  \nFigure 1. Research Methodology\n\n• “Visualize The Alternative Path” where the user can visualize the alternative path after the block is placed (Figure 13).  \n• “Generate Congestion prediction” where the user can visualize the predictions on the alternative path the block is placed. \nHere user can select for which segment of the alternative path he wants the congestion predictions from another drop -down \noption. \nThe predictions are displayed in four different colors red (75%-100% congestion chances), Orange (50%-74% congestion \nchances), Yellow (25%-49% congestion chances), and green (0%-24% congestion chances). \n \n (a) (b) \nFigure 11. (a) Alternative path between two nodes generated by A-Star algorithm after placing a \nblock. (b) Actual path between two nodes generated by A-Star algorithm before placing a block.\n</context>\nQuestion: What are the main contributions of the paper?\n<answer>\nThe main contributions of the paper are:\n1.  The development of a machine learning model for optimal route selection.\n2.  The use of Ada Boost Classifier for predicting traffic congestion.\n3.  The implementation of the A-Star algorithm for alternative path selection.\n4.  The visualization of alternative paths and congestion predictions.\n5.  The contribution to the advancement of smart traffic management systems.\n</answer>\n'}
